# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# for colab to check if modules has changed
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/content/drive/MyDrive/TagYourMoves') # Adjust path if needed

from src.core.pipeline import BasketballInferencePipeline

# 1. Configuration Paths
YOLO_PATH = '/content/drive/MyDrive/basketball/nba_multi_class/yolov8s_combined/weights/best.pt'
LSTM_PATH = '/content/drive/MyDrive/basketball/lstm_model.pt'
SCALER_PATH = '/content/drive/MyDrive/basketball/scaler.pkl'
INPUT_VIDEO = '/content/drive/MyDrive/basketball/VIDEOS_NO_DETECTION/vid1.mp4'
OUTPUT_VIDEO = '/content/inference_videos/basketball_production_output.mp4'

# 2. Initialize and Run the entire architecture in one line!
pipeline = BasketballInferencePipeline(YOLO_PATH, LSTM_PATH, SCALER_PATH, confidence_threshold=0.85)
pipeline.run(INPUT_VIDEO, OUTPUT_VIDEO)
